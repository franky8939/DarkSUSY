# %%
import numpy as np
import matplotlib.pyplot as plt
# Constantes
a_const =137**(-1)
c_const =1
e_const =1
a_const*e_const
i = 1
#Mass_lepton = [])
Mass_lepton = np.array([0.511*10**(-3), 105.7*10**(-3), 1.777]) # GeV
Mass_DPho = np.linspace(0.25, 10, 100) # GeV

#print np.sqrt(4*Mass_lepton[1]**2/Mass_DPho**2)

Pmumu = a_const*Mass_DPho*np.sqrt(1-(4*Mass_lepton[1]**2)/(Mass_DPho**2))* \
        (1 + (2*Mass_lepton[i]**2)/(Mass_DPho**2))*3**(-1)
#print Pmumu, np.sqrt(1-(4*Mass_lepton[1]**2)/(Mass_DPho**2)), a_const


fig = plt.figure()
ax = fig.add_subplot(223)
ax.plot(Mass_DPho,Pmumu)
ax.grid(True)
#ax.set_title(' Resolucion del momento para el Muon, CMS en Alta Luminosidad', y=1.08)
#ax.set_xlabel(" Angulo Eta ")
#ax.set_ylabel(" Resolucion del momento $\dfrac{\Delta P}{P}$(%) ")

# %%
from matplotlib import cm

#from matplotlib.ticker import LinearLocator, FormatStrFormatter
from mpl_toolkits.mplot3d import Axes3D

# VARIABLES A TRATAR
pt = np.linspace(1, 300, 101)
eta = np.linspace(1, 4.1, 101)
pt_m, eta_m = np.meshgrid(pt, eta)

def Mu_efi(eta_mesh, pt_mesh, n="CMS"):
    if n is "CMS":
        ###################################
        # Muon tracking efficiency Default
        ###################################
        out = \
            (pt_mesh <= 10.0) * 0.00 + \
            (abs(eta_mesh) <= 1.5) * (pt_mesh > 10.0) * 0.95 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.4) * (pt_mesh > 10.0) * 0.95 + \
            (abs(eta_mesh) > 2.4) * 0.00
    elif n in ["HL", "HL2"]:
        #############################
        # Muon tracking efficiency HL
        #############################
        out = \
            (pt_mesh <= 2.0) * 0.00 + \
            (abs(eta_mesh) > 0.0 )*( abs(eta_mesh) <= 0.5) * (pt_mesh > 2.0 )*( pt_mesh <= 4.0) * 0.04 + \
            (abs(eta_mesh) > 0.0 )*( abs(eta_mesh) <= 0.5) * (pt_mesh > 4.0 )*( pt_mesh <= 6.0) * 0.43 + \
            (abs(eta_mesh) > 0.0 )*( abs(eta_mesh) <= 0.5) * (pt_mesh > 6.0 )*( pt_mesh <= 8.0) * 0.53 + \
            (abs(eta_mesh) > 0.0 )*( abs(eta_mesh) <= 0.5) * (pt_mesh > 8.0 )*( pt_mesh <= 10.0) * 0.68 + \
            (abs(eta_mesh) > 0.0 )*( abs(eta_mesh) <= 0.5) * (pt_mesh > 10.0 )*( pt_mesh <= 20.0) * 0.81 + \
            (abs(eta_mesh) > 0.0 )*( abs(eta_mesh) <= 0.5) * (pt_mesh > 20.0 )*( pt_mesh <= 35.0) * 0.91 + \
            (abs(eta_mesh) > 0.0 )*( abs(eta_mesh) <= 0.5) * (pt_mesh > 35.0 )*( pt_mesh <= 50.0) * 0.96 + \
            (abs(eta_mesh) > 0.0 )*( abs(eta_mesh) <= 0.5) * (pt_mesh > 50.0 )*( pt_mesh <= 14000.0) * 0.91 + \
            (abs(eta_mesh) > 0.5 )*( abs(eta_mesh) <= 1.0) * (pt_mesh > 2.0 )*( pt_mesh <= 4.0) * 0.05 + \
            (abs(eta_mesh) > 0.5 )*( abs(eta_mesh) <= 1.0) * (pt_mesh > 4.0 )*( pt_mesh <= 6.0) * 0.47 + \
            (abs(eta_mesh) > 0.5 )*( abs(eta_mesh) <= 1.0) * (pt_mesh > 6.0 )*( pt_mesh <= 8.0) * 0.56 + \
            (abs(eta_mesh) > 0.5 )*( abs(eta_mesh) <= 1.0) * (pt_mesh > 8.0 )*( pt_mesh <= 10.0) * 0.69 + \
            (abs(eta_mesh) > 0.5 )*( abs(eta_mesh) <= 1.0) * (pt_mesh > 10.0 )*( pt_mesh <= 20.0) * 0.79 + \
            (abs(eta_mesh) > 0.5 )*( abs(eta_mesh) <= 1.0) * (pt_mesh > 20.0 )*( pt_mesh <= 35.0) * 0.93 + \
            (abs(eta_mesh) > 0.5 )*( abs(eta_mesh) <= 1.0) * (pt_mesh > 35.0 )*( pt_mesh <= 50.0) * 0.94 + \
            (abs(eta_mesh) > 0.5 )*( abs(eta_mesh) <= 1.0) * (pt_mesh > 50.0 )*( pt_mesh <= 14000.0) * 0.91 + \
            (abs(eta_mesh) > 1.0 )*( abs(eta_mesh) <= 1.5) * (pt_mesh > 2.0 )*( pt_mesh <= 4.0) * 0.16 + \
            (abs(eta_mesh) > 1.0 )*( abs(eta_mesh) <= 1.5) * (pt_mesh > 4.0 )*( pt_mesh <= 6.0) * 0.48 + \
            (abs(eta_mesh) > 1.0 )*( abs(eta_mesh) <= 1.5) * (pt_mesh > 6.0 )*( pt_mesh <= 8.0) * 0.53 + \
            (abs(eta_mesh) > 1.0 )*( abs(eta_mesh) <= 1.5) * (pt_mesh > 8.0 )*( pt_mesh <= 10.0) * 0.66 + \
            (abs(eta_mesh) > 1.0 )*( abs(eta_mesh) <= 1.5) * (pt_mesh > 10.0 )*( pt_mesh <= 20.0) * 0.79 + \
            (abs(eta_mesh) > 1.0 )*( abs(eta_mesh) <= 1.5) * (pt_mesh > 20.0 )*( pt_mesh <= 35.0) * 0.89 + \
            (abs(eta_mesh) > 1.0 )*( abs(eta_mesh) <= 1.5) * (pt_mesh > 35.0 )*( pt_mesh <= 50.0) * 0.95 + \
            (abs(eta_mesh) > 1.0 )*( abs(eta_mesh) <= 1.5) * (pt_mesh > 50.0 )*( pt_mesh <= 14000.0) * 0.91 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.0) * (pt_mesh > 2.0 )*( pt_mesh <= 4.0) * 0.24 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.0) * (pt_mesh > 4.0 )*( pt_mesh <= 6.0) * 0.44 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.0) * (pt_mesh > 6.0 )*( pt_mesh <= 8.0) * 0.51 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.0) * (pt_mesh > 8.0 )*( pt_mesh <= 10.0) * 0.71 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.0) * (pt_mesh > 10.0 )*( pt_mesh <= 20.0) * 0.77 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.0) * (pt_mesh > 20.0 )*( pt_mesh <= 35.0) * 0.91 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.0) * (pt_mesh > 35.0 )*( pt_mesh <= 50.0) * 0.92 + \
            (abs(eta_mesh) > 1.5 )*( abs(eta_mesh) <= 2.0) * (pt_mesh > 50.0 )*( pt_mesh <= 14000.0) * 0.91 + \
            (abs(eta_mesh) > 2.0 )*( abs(eta_mesh) <= 2.5) * (pt_mesh > 2.0 )*( pt_mesh <= 4.0) * 0.23 + \
            (abs(eta_mesh) > 2.0 )*( abs(eta_mesh) <= 2.5) * (pt_mesh > 4.0 )*( pt_mesh <= 6.0) * 0.35 + \
            (abs(eta_mesh) > 2.0 )*( abs(eta_mesh) <= 2.5) * (pt_mesh > 6.0 )*( pt_mesh <= 8.0) * 0.43 + \
            (abs(eta_mesh) > 2.0 )*( abs(eta_mesh) <= 2.5) * (pt_mesh > 8.0 )*( pt_mesh <= 10.0) * 0.57 + \
            (abs(eta_mesh) > 2.0 )*( abs(eta_mesh) <= 2.5) * (pt_mesh > 10.0 )*( pt_mesh <= 20.0) * 0.63 + \
            (abs(eta_mesh) > 2.0 )*( abs(eta_mesh) <= 2.5) * (pt_mesh > 20.0 )*( pt_mesh <= 35.0) * 0.71 + \
            (abs(eta_mesh) > 2.0 )*( abs(eta_mesh) <= 2.5) * (pt_mesh > 35.0 )*( pt_mesh <= 50.0) * 0.76 + \
            (abs(eta_mesh) > 2.0 )*( abs(eta_mesh) <= 2.5) * (pt_mesh > 50.0 )*( pt_mesh <= 14000.0) * 0.81 + \
            (abs(eta_mesh) > 2.5 )*( abs(eta_mesh) <= 4.0 ) * (pt_mesh > 2.0 )*( pt_mesh <= 4.0) * 0.05 + \
            (abs(eta_mesh) > 2.5 )*( abs(eta_mesh) <= 4.0 ) * (pt_mesh > 4.0 )*( pt_mesh <= 10.0) * 0.65 + \
            (abs(eta_mesh) > 2.5 )*( abs(eta_mesh) <= 4.0 ) * (pt_mesh > 10.0 )*( pt_mesh <= 30.0) * 0.75 + \
            (abs(eta_mesh) > 2.5 )*( abs(eta_mesh) <= 4.0 ) * (pt_mesh > 30.0 )*( pt_mesh <= 50.0) * 0.90 + \
            (abs(eta_mesh) > 2.5 )*( abs(eta_mesh) <= 4.0 ) * (pt_mesh > 50.0 )*( pt_mesh <= 70.0) * 0.90 + \
            (abs(eta_mesh) > 2.5 )*( abs(eta_mesh) <= 4.0 ) * (pt_mesh > 70.0 ) * 0.90 + \
            (abs(eta_mesh) > 4.0) * 0.00
    else:
        out = False
    return out

### Momentum resolution ###
Mu_efi_D = Mu_efi(eta_m, pt_m,"CMS")*100
Mu_efi_HL = Mu_efi(eta_m, pt_m, "HL")*100
Mu_efi_HL2 = Mu_efi(eta_m, pt_m, "HL2")*100
Mu_efi_diffHL2 = Mu_efi_HL2 - Mu_efi_D
#Mu_efi_ratio = (Mu_efi_D)/Mu_efi_HL

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = plt.figure()
## DEFAULT ##
ax = fig.add_subplot(221, projection='3d')
plot1 = ax.plot_surface(eta_m, 
                        pt_m, 
                        Mu_efi_D , cmap = 'cividis',
                        linewidth=1)
ax.set_zlim(0, np.max(Mu_efi_HL) + 5)

ax.set_title("Eficiencia de los muones" + "\n" + "CMS en Fase 1", y=1.08)
ax.set_xlabel(' Angulo Eta')
ax.set_ylabel(" Momento Transversal (GeV)")
ax.set_zlabel(" Eficiencia de muones (%)")
#ax.set_tick_params(labelsize=20)
ax.view_init(30, -45)
fig.colorbar(plot1, shrink=0.5, aspect=5)

## ALTA LUMINOSIDAD ##
ax = fig.add_subplot(222, projection='3d')
plot2 = ax.plot_surface(eta_m, 
                        pt_m, 
                        Mu_efi_HL , cmap = 'cividis')
ax.set_zlim(0, np.max(Mu_efi_HL) + 5)
ax.set_title("Eficiencia de muones" + "\n" +"CMS en Alta Luminosidad", y=1.08)
ax.set_xlabel(' Angulo Eta')
ax.set_ylabel(" Momento Transversal (GeV)")
ax.set_zlabel(" Eficiencia de muones (%)")
ax.view_init(30, -45)
fig.colorbar(plot2, shrink=0.5, aspect=5)

## DEFAULT PLOT ##
ax = fig.add_subplot(223)
ax.plot(eta_m[:,0], Mu_efi_D[:,0], 
        label="Valores a $P_T$ = "+str(pt_m[0,0])+" GeV")
ax.plot(eta_m[:, np.round(eta_m.shape[0]/3)],  Mu_efi_D[:, np.round(eta_m.shape[0]/3)],
        label="Valores a $P_T$ = "+str(round(pt_m[0,np.round(eta_m.shape[0]/3)]))+" GeV")
ax.plot(eta_m[:, np.round(eta_m.shape[0]*2/3)],  Mu_efi_D[:, np.round(eta_m.shape[0]*2/3)],
        label="Valores a $P_T$ = "+str(round(pt_m[0,np.round(eta_m.shape[0]*2/3)]))+" GeV")
ax.plot(eta_m[:,-1],  Mu_efi_D[:,-1],
        label="Valores a $P_T$ = "+str(round(pt_m[0,-1]))+" GeV")

ax.legend(loc="lower left", frameon=False)
ax.set_ylim(0, np.max(Mu_efi_D) + 5)
ax.grid(True)
#ax.set_title(' Resolucion del momento para el Muon, CMS en Alta Luminosidad', y=1.08)
ax.set_xlabel(" Angulo Eta ")
ax.set_ylabel(" Eficiencia de muones (%) ")

## HL PLOT ##
ax = fig.add_subplot(224)
ax.plot(eta_m[:,0], Mu_efi_HL[:,0], 
        label="Valores a $P_T$ = "+str(pt_m[0,0])+" GeV")
ax.plot(eta_m[:, np.round(eta_m.shape[0]/3)],  Mu_efi_HL[:, np.round(eta_m.shape[0]/3)],
        label="Valores a $P_T$ = "+str(round(pt_m[0,np.round(eta_m.shape[0]/3)]))+" GeV")
ax.plot(eta_m[:, np.round(eta_m.shape[0]*2/3)],  Mu_efi_HL[:, np.round(eta_m.shape[0]*2/3)],
        label="Valores a $P_T$ = "+str(round(pt_m[0,np.round(eta_m.shape[0]*2/3)]))+" GeV")
ax.plot(eta_m[:,-1],  Mu_efi_HL[:,-1],
        label="Valores a $P_T$ = "+str(round(pt_m[0,-1]))+" GeV")

ax.legend(loc="lower left", frameon=False)
ax.set_ylim(0, np.max(Mu_efi_HL) + 5)
ax.grid(True)
#ax.set_title(' Resolucion del momento para el Muon, CMS en Alta Luminosidad', y=1.08)
ax.set_xlabel(" Angulo Eta ")
ax.set_ylabel(" Eficiencia de muones (%) ")

plt.savefig("files_PDF/Eficiencia_of_Muon.png")
